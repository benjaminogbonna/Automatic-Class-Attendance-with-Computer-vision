# %%
# notebook imports

import math
import os
import pathlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import matplotlib.image as mpimg
import random
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Conv2D, MaxPooling2D, Activation, BatchNormalization, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img

# %%
# make model call backs

save_path = 'model_experiments'

def create_model_checkpoint(model_name, save_path=save_path):
    return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name),
                                              verbose=0, 
                                              save_best_only=True)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                  patience=50,
                                                  restore_best_weights=True)

reduce_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                      patience=500,
                                                      verbose=1)

# %%
# helper functions
from helper_functions import plot_loss_curves, unzip_data, compare_historys, walk_through_dir

# %%
train_dir = 'data/train'
validation_dir = 'data/validation'

# %%
import os
from PIL import Image
folder_path = 'data/validation/'
extensions = []
for fldr in os.listdir(folder_path):
    sub_folder_path = os.path.join(folder_path, fldr)
    for filee in os.listdir(sub_folder_path):
        file_path = os.path.join(sub_folder_path, filee)
        print('** Path: {}  **'.format(file_path), end="\r", flush=True)
        im = Image.open(file_path)
        rgb_im = im.convert('RGB')
        if filee.split('.')[1] not in extensions:
            extensions.append(filee.split('.')[1])
# Out:
# ** Path: data/validation/Image9\IMG99.JPG  *****

# %%
# How many images/classes are there?
walk_through_dir("data")
# Out:
# There are 2 directories and 0 images in 'data'.
# There are 20 directories and 0 images in 'data\train'.
# There are 0 directories and 7 images in 'data\train\Image1'.
# There are 0 directories and 7 images in 'data\train\Image10'.
# There are 0 directories and 7 images in 'data\train\Image11'.
# There are 0 directories and 7 images in 'data\train\Image12'.
# There are 0 directories and 7 images in 'data\train\Image13'.
# There are 0 directories and 7 images in 'data\train\Image14'.
# There are 0 directories and 7 images in 'data\train\Image15'.
# There are 0 directories and 7 images in 'data\train\Image16'.
# There are 0 directories and 7 images in 'data\train\Image17'.
# There are 0 directories and 7 images in 'data\train\Image18'.
# There are 0 directories and 7 images in 'data\train\Image19'.
# There are 0 directories and 7 images in 'data\train\Image2'.
# There are 0 directories and 7 images in 'data\train\Image20'.
# There are 0 directories and 7 images in 'data\train\Image3'.
# There are 0 directories and 7 images in 'data\train\Image4'.
# There are 0 directories and 7 images in 'data\train\Image5'.
# There are 0 directories and 7 images in 'data\train\Image6'.
# There are 0 directories and 7 images in 'data\train\Image7'.
# There are 0 directories and 7 images in 'data\train\Image8'.
# There are 0 directories and 7 images in 'data\train\Image9'.
# There are 20 directories and 0 images in 'data\validation'.
# There are 0 directories and 3 images in 'data\validation\Image1'.
# There are 0 directories and 3 images in 'data\validation\Image10'.
# There are 0 directories and 3 images in 'data\validation\Image11'.
# There are 0 directories and 3 images in 'data\validation\Image12'.
# There are 0 directories and 3 images in 'data\validation\Image13'.
# There are 0 directories and 3 images in 'data\validation\Image14'.
# There are 0 directories and 3 images in 'data\validation\Image15'.
# There are 0 directories and 3 images in 'data\validation\Image16'.
# There are 0 directories and 3 images in 'data\validation\Image17'.
# There are 0 directories and 3 images in 'data\validation\Image18'.
# There are 0 directories and 3 images in 'data\validation\Image19'.
# There are 0 directories and 3 images in 'data\validation\Image2'.
# There are 0 directories and 3 images in 'data\validation\Image20'.
# There are 0 directories and 3 images in 'data\validation\Image3'.
# There are 0 directories and 3 images in 'data\validation\Image4'.
# There are 0 directories and 3 images in 'data\validation\Image5'.
# There are 0 directories and 3 images in 'data\validation\Image6'.
# There are 0 directories and 3 images in 'data\validation\Image7'.
# There are 0 directories and 3 images in 'data\validation\Image8'.
# There are 0 directories and 3 images in 'data\validation\Image9'.

# %%
# Get the class names (programmatically, this is much more helpful with a longer list of classes)

data_dir = pathlib.Path("data/train/") 
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['Image1' 'Image10' 'Image11' 'Image12' 'Image13' 'Image14' 'Image15'
#  'Image16' 'Image17' 'Image18' 'Image19' 'Image2' 'Image20' 'Image3'
#  'Image4' 'Image5' 'Image6' 'Image7' 'Image8' 'Image9']

# %%
# set target and batch size of image
TARGET_SIZE = (224, 224)
BATCH_SIZE = 128

# Set the seed
tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 1 and 0, also called scaling/normalization)

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=BATCH_SIZE, 
                                               target_size=TARGET_SIZE,
                                               class_mode="categorical", 
                                               seed=42)

valid_data = validation_datagen.flow_from_directory(validation_dir,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=TARGET_SIZE,
                                                    class_mode="categorical",
                                                    seed=42)
# Out:
# Found 140 images belonging to 20 classes.
# Found 60 images belonging to 20 classes.

# %% [markdown]
# # Model 0

# %%
# creat model: Base model

num_classes = len(class_names)

# Create a CNN model
lenet_0 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=10, 
                           kernel_size=3, 
                           activation="relu",
                           input_shape=(224, 224, 3)),
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Conv2D(10, 3, activation="relu"), 
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(num_classes, activation="softmax")
], name='lenet_0')

# Compile the model
lenet_0.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
lenet_0.summary()
# Out:
# Model: "lenet_0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 20)                561820
#
# =================================================================
# Total params: 564,830
# Trainable params: 564,830
# Non-trainable params: 0
# _________________________________________________________________

# %%
lenet_0.name
# Out:
# 'lenet_0'

# %%
# %%time
# Fit the model
callbacks_list = [create_model_checkpoint(lenet_0.name), early_stopping, reduce_plateau]

lenet_history_0 = lenet_0.fit(train_data,
                        epochs=10,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data),
                        callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 2/2 [==============================] - ETA: 0s - loss: 3.1022 - accuracy: 0.0714    INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 28s 24s/step - loss: 3.1022 - accuracy: 0.0714 - val_loss: 3.0146 - val_accuracy: 0.1000 - lr: 0.0010
# Epoch 2/10
# 2/2 [==============================] - ETA: 0s - loss: 2.9795 - accuracy: 0.0571INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 31s 29s/step - loss: 2.9795 - accuracy: 0.0571 - val_loss: 2.9612 - val_accuracy: 0.0500 - lr: 0.0010
# Epoch 3/10
# 2/2 [==============================] - ETA: 0s - loss: 2.9281 - accuracy: 0.0500INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 23s 22s/step - loss: 2.9281 - accuracy: 0.0500 - val_loss: 2.9405 - val_accuracy: 0.0500 - lr: 0.0010
# Epoch 4/10
# 2/2 [==============================] - ETA: 0s - loss: 2.8938 - accuracy: 0.0857 INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 23s 10s/step - loss: 2.8938 - accuracy: 0.0857 - val_loss: 2.9074 - val_accuracy: 0.1500 - lr: 0.0010
# Epoch 5/10
# 2/2 [==============================] - ETA: 0s - loss: 2.8281 - accuracy: 0.3357 INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 19s 7s/step - loss: 2.8281 - accuracy: 0.3357 - val_loss: 2.8465 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 6/10
# 2/2 [==============================] - ETA: 0s - loss: 2.6670 - accuracy: 0.3786INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 21s 20s/step - loss: 2.6670 - accuracy: 0.3786 - val_loss: 2.7608 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 7/10
# 2/2 [==============================] - ETA: 0s - loss: 2.4873 - accuracy: 0.5500INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 21s 20s/step - loss: 2.4873 - accuracy: 0.5500 - val_loss: 2.6148 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 8/10
# 2/2 [==============================] - ETA: 0s - loss: 2.1996 - accuracy: 0.6500INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 23s 22s/step - loss: 2.1996 - accuracy: 0.6500 - val_loss: 2.4029 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/10
# 2/2 [==============================] - ETA: 0s - loss: 1.9758 - accuracy: 0.7714 INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 22s 7s/step - loss: 1.9758 - accuracy: 0.7714 - val_loss: 2.1603 - val_accuracy: 0.4500 - lr: 0.0010
# Epoch 10/10
# 2/2 [==============================] - ETA: 0s - loss: 1.4513 - accuracy: 0.7786INFO:tensorflow:Assets written to: model_experiments\lenet_0\assets
# 2/2 [==============================] - 25s 24s/step - loss: 1.4513 - accuracy: 0.7786 - val_loss: 2.0049 - val_accuracy: 0.4000 - lr: 0.0010
# Wall time: 4min 10s

# %%
lenet_0.evaluate(valid_data)
# Out:
# 1/1 [==============================] - 4s 4s/step - loss: 2.0049 - accuracy: 0.4000
# [2.004911184310913, 0.4000000059604645]

# %%
saved_lenet_0 = tf.keras.models.load_model('model_experiments/lenet_0/')
saved_lenet_0.evaluate(valid_data)
# Out:
# 1/1 [==============================] - 4s 4s/step - loss: 2.0049 - accuracy: 0.4000
# [2.004911184310913, 0.4000000059604645]

# %%
# make Prediction

# Create a function to import an image and resize it to be able to be used with our model
def plot_and_pred(model, filename, img_shape=224):
    img = tf.io.read_file(filename)

    img = tf.image.decode_image(img, channels=3)

    img = tf.image.resize(img, size = [img_shape, img_shape])

    img = img/255.
    
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    prob = f'{math.ceil(pred.max()*100)}%'
    pred_class = class_names[int(np.argmax(pred))]
    
    plt.title(f'{pred_class.title()} {prob}')
#     plt.xlabel(cuisines[pred_class])
    plt.grid(False)
    plt.axis(False)
    plt.imshow(np.squeeze(img))
    
    return pred_class

# %%
# plt.figure(figsize=(5, 5))
p = plot_and_pred(lenet_0, 'data/test2.jpg')

# %%
pd.DataFrame(lenet_history_0.history).plot(figsize=(10, 7))
# Out:
# <AxesSubplot:>

# %%
def load_and_prep_image(filename, img_shape=224):
    img = tf.io.read_file(filename)

    img = tf.image.decode_image(img, channels=3)

    img = tf.image.resize(img, size = [img_shape, img_shape])

    img = img/255.
    
    img = tf.expand_dims(img, axis=0)
    
    return img

sample_image = load_and_prep_image("data/12.jpg")
pred = model_0.predict(sample_image)
prob = math.ceil(pred.max()*100)
pred_class = class_names[int(np.argmax(pred))]
print(f'Prediction: {pred_class} \nConf: {prob}%')
# Out:
# Prediction: 001
# Conf: 43%

# %% [markdown]
# # Model 1
# ## same model as model 0, but with data augmentation

# %%
# set target and batch size of image
TARGET_SIZE = (224, 224)
BATCH_SIZE = 128

# Set the seed
tf.random.set_seed(42)

train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=.2,
                                   zoom_range=.2,
                                   width_shift_range=.1,
                                   height_shift_range=.1,
                                   rotation_range=20,
                                   horizontal_flip=True)

validation_datagen = ImageDataGenerator(rescale= 1./255)

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=BATCH_SIZE, 
                                               target_size=TARGET_SIZE,
                                               class_mode="categorical", 
                                               seed=42)

valid_data = validation_datagen.flow_from_directory(validation_dir,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=TARGET_SIZE,                                            
                                                    class_mode="categorical",
                                                    seed=42)
# Out:
# Found 163 images belonging to 17 classes.
# Found 82 images belonging to 17 classes.

# %%
# create model: model 1

num_classes = len(class_names)

# Create a CNN model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=10, 
                           kernel_size=3, 
                           activation="relu",
                           input_shape=(224, 224, 3)),
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Conv2D(10, 3, activation="relu"), 
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(num_classes, activation="softmax")
], name='model_1')

# Compile the model
model_1.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
# %%time
# Fit the model
callbacks_list = [create_model_checkpoint(model_1.name), early_stopping, reduce_plateau]

history_1 = model_1.fit(train_data,
                        epochs=15,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data),
                        callbacks=callbacks_list)
# Out:
# Epoch 1/15
# 2/2 [==============================] - ETA: 0s - loss: 3.0375 - accuracy: 0.0552 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 27s 13s/step - loss: 3.0375 - accuracy: 0.0552 - val_loss: 2.8605 - val_accuracy: 0.0610 - lr: 0.0010
# Epoch 2/15
# 2/2 [==============================] - ETA: 0s - loss: 2.8581 - accuracy: 0.0613 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 25s 12s/step - loss: 2.8581 - accuracy: 0.0613 - val_loss: 2.8148 - val_accuracy: 0.1220 - lr: 0.0010
# Epoch 3/15
# 2/2 [==============================] - ETA: 0s - loss: 2.8266 - accuracy: 0.0982INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 20s/step - loss: 2.8266 - accuracy: 0.0982 - val_loss: 2.8013 - val_accuracy: 0.0854 - lr: 0.0010
# Epoch 4/15
# 2/2 [==============================] - ETA: 0s - loss: 2.8079 - accuracy: 0.1043INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 20s/step - loss: 2.8079 - accuracy: 0.1043 - val_loss: 2.7596 - val_accuracy: 0.1098 - lr: 0.0010
# Epoch 5/15
# 2/2 [==============================] - ETA: 0s - loss: 2.7782 - accuracy: 0.1043INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 20s/step - loss: 2.7782 - accuracy: 0.1043 - val_loss: 2.7240 - val_accuracy: 0.0732 - lr: 0.0010
# Epoch 6/15
# 2/2 [==============================] - ETA: 0s - loss: 2.7382 - accuracy: 0.1227 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 23s 10s/step - loss: 2.7382 - accuracy: 0.1227 - val_loss: 2.6317 - val_accuracy: 0.2561 - lr: 0.0010
# Epoch 7/15
# 2/2 [==============================] - ETA: 0s - loss: 2.6664 - accuracy: 0.2515 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 11s/step - loss: 2.6664 - accuracy: 0.2515 - val_loss: 2.5311 - val_accuracy: 0.2317 - lr: 0.0010
# Epoch 8/15
# 2/2 [==============================] - ETA: 0s - loss: 2.5868 - accuracy: 0.2454 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 23s 10s/step - loss: 2.5868 - accuracy: 0.2454 - val_loss: 2.3887 - val_accuracy: 0.3171 - lr: 0.0010
# Epoch 9/15
# 2/2 [==============================] - ETA: 0s - loss: 2.4345 - accuracy: 0.2025 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 11s/step - loss: 2.4345 - accuracy: 0.2025 - val_loss: 2.3256 - val_accuracy: 0.2561 - lr: 0.0010
# Epoch 10/15
# 2/2 [==============================] - ETA: 0s - loss: 2.3256 - accuracy: 0.2454INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 23s 19s/step - loss: 2.3256 - accuracy: 0.2454 - val_loss: 2.1861 - val_accuracy: 0.3293 - lr: 0.0010
# Epoch 11/15
# 2/2 [==============================] - ETA: 0s - loss: 2.2101 - accuracy: 0.2883 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 11s/step - loss: 2.2101 - accuracy: 0.2883 - val_loss: 2.0639 - val_accuracy: 0.3659 - lr: 0.0010
# Epoch 12/15
# 2/2 [==============================] - ETA: 0s - loss: 2.1360 - accuracy: 0.3374 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 25s 11s/step - loss: 2.1360 - accuracy: 0.3374 - val_loss: 1.9618 - val_accuracy: 0.4024 - lr: 0.0010
# Epoch 13/15
# 2/2 [==============================] - ETA: 0s - loss: 2.1211 - accuracy: 0.3865 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 11s/step - loss: 2.1211 - accuracy: 0.3865 - val_loss: 1.9521 - val_accuracy: 0.4268 - lr: 0.0010
# Epoch 14/15
# 2/2 [==============================] - ETA: 0s - loss: 2.0018 - accuracy: 0.4110 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 10s/step - loss: 2.0018 - accuracy: 0.4110 - val_loss: 1.9260 - val_accuracy: 0.4268 - lr: 0.0010
# Epoch 15/15
# 2/2 [==============================] - ETA: 0s - loss: 2.0055 - accuracy: 0.4049 INFO:tensorflow:Assets written to: model_experiments\model_1\assets
# 2/2 [==============================] - 24s 11s/step - loss: 2.0055 - accuracy: 0.4049 - val_loss: 1.8548 - val_accuracy: 0.4512 - lr: 0.0010
# Wall time: 6min 25s

# %%
model_1.evaluate(valid_data)
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 1.8548 - accuracy: 0.4512
# [1.854767084121704, 0.45121949911117554]

# %%
saved_model_1 = tf.keras.models.load_model('model_experiments/model_1/')
saved_model_1.evaluate(valid_data)
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 1.8548 - accuracy: 0.4512
# [1.854767084121704, 0.45121949911117554]

# %%
pd.DataFrame(history_1.history).plot(figsize=(10, 7))
# Out:
# <AxesSubplot:>

# %%
compare_historys(history_0, history_1)

# %%
p = plot_and_pred(model_1, 'data/12.jpg')

# %% [markdown]
# # Model 2
# ## same model as model 1, but with full dataset

# %%
# set target and batch size of image
TARGET_SIZE = (224, 224)
BATCH_SIZE = 128

# Set the seed
tf.random.set_seed(42)

train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=.2,
                                   zoom_range=.2,
                                   width_shift_range=.1,
                                   height_shift_range=.1,
                                   rotation_range=20,
                                   horizontal_flip=True)

validation_datagen = ImageDataGenerator(rescale= 1./255)

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=BATCH_SIZE, 
                                               target_size=TARGET_SIZE,
                                               class_mode="categorical", 
                                               seed=42)

valid_data = validation_datagen.flow_from_directory(validation_dir,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=TARGET_SIZE,
                                                    class_mode="categorical",
                                                    seed=42)
# Out:
# Found 2475 images belonging to 18 classes.
# Found 616 images belonging to 18 classes.

# %%
# create model: model 2

num_classes = len(class_names)

# Create a CNN model
model_2 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=10, 
                           kernel_size=3, 
                           activation="relu",
                           input_shape=(224, 224, 3)),
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Conv2D(10, 3, activation="relu"), 
    tf.keras.layers.Conv2D(10, 3, activation="relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(num_classes, activation="softmax")
], name='model_2')

# Compile the model
model_2.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
model_2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 18)                505638
#
# =================================================================
# Total params: 508,648
# Trainable params: 508,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# Fit the model
callbacks_list = [create_model_checkpoint(model_2.name), early_stopping, reduce_plateau]

history_2 = model_2.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data),
                        callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 20/20 [==============================] - ETA: 0s - loss: 2.7585 - accuracy: 0.1236 INFO:tensorflow:Assets written to: model_experiments\model_2\assets
# 20/20 [==============================] - 320s 16s/step - loss: 2.7585 - accuracy: 0.1236 - val_loss: 2.6092 - val_accuracy: 0.1899 - lr: 0.0010
# Epoch 2/5
# 20/20 [==============================] - ETA: 0s - loss: 2.4347 - accuracy: 0.2242INFO:tensorflow:Assets written to: model_experiments\model_2\assets
# 20/20 [==============================] - 166s 8s/step - loss: 2.4347 - accuracy: 0.2242 - val_loss: 2.4717 - val_accuracy: 0.2305 - lr: 0.0010
# Epoch 3/5
# 20/20 [==============================] - ETA: 0s - loss: 2.2837 - accuracy: 0.2586INFO:tensorflow:Assets written to: model_experiments\model_2\assets
# 20/20 [==============================] - 243s 12s/step - loss: 2.2837 - accuracy: 0.2586 - val_loss: 2.3036 - val_accuracy: 0.2565 - lr: 0.0010
# Epoch 4/5
# 20/20 [==============================] - 466s 23s/step - loss: 2.1904 - accuracy: 0.2994 - val_loss: 2.3782 - val_accuracy: 0.2532 - lr: 0.0010
# Epoch 5/5
# 20/20 [==============================] - ETA: 0s - loss: 2.1052 - accuracy: 0.3212 INFO:tensorflow:Assets written to: model_experiments\model_2\assets
# 20/20 [==============================] - 468s 23s/step - loss: 2.1052 - accuracy: 0.3212 - val_loss: 2.1997 - val_accuracy: 0.3360 - lr: 0.0010
# Wall time: 28min 34s

# %%
pd.DataFrame(history_2.history).plot()
# Out:
# <AxesSubplot:>

# %%
model_2.evaluate(valid_data)
# Out:
# 5/5 [==============================] - 78s 15s/step - loss: 2.1997 - accuracy: 0.3360
# [2.1997134685516357, 0.3360389471054077]

# %%
saved_model = tf.keras.models.load_model('model_experiments/model_2/')
saved_model.evaluate(valid_data)
# Out:
# 5/5 [==============================] - 64s 12s/step - loss: 2.1997 - accuracy: 0.3360
# [2.199713706970215, 0.3360389471054077]

# %%
p = plot_and_pred(model_2, '58.jpg')
cuisines[p]

# %%
p = plot_and_pred(model_2, '25.jpg')
# cuisines[p]

# %%
class_names = ['abacha', 'akara', 'jellof_rice', 'moin_moin', 'pounded_yam', 'suya']

def plot_and_pred(model, filename, img_shape=224):
    img = tf.io.read_file(filename)

    img = tf.image.decode_image(img, channels=3)

    img = tf.image.resize(img, size = [img_shape, img_shape])

    img = img/255.
    
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    prob = f'{math.ceil(pred.max()*100)}%'
    pred_class = class_names[int(np.argmax(pred))]
    
    plt.title(f'{pred_class.title()} {prob}')
#     plt.xlabel(cuisines[pred_class])
    plt.grid(False)
    plt.axis(False)
    plt.imshow(np.squeeze(img))
    
    return pred_class

# %%
model = tf.keras.models.load_model('saved_models/model_0.h5')
model_0_saved = tf.keras.models.load_model('saved_models/model_0_saved.h5')

# %%
test_image = 'test/1.jpeg'

# %%
plot_and_pred(model, test_image)
# Out:
# 'abacha'

# %%
plot_and_pred(model_0_saved, test_image)
# Out:
# 'abacha'

# %%
# set target and batch size of image
TARGET_SIZE = (224, 224)
BATCH_SIZE = 128

# Set the seed
tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 1 and 0, also called scaling/normalization)

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=BATCH_SIZE, 
                                               target_size=TARGET_SIZE,
                                               color_mode="grayscale",
                                               class_mode="categorical", 
                                               seed=42)

valid_data = validation_datagen.flow_from_directory(validation_dir,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=TARGET_SIZE,
                                                    color_mode="grayscale",
                                                    class_mode="categorical",
                                                    seed=42)
